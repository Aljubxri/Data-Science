# %% [markdown]
# # Project 3
# __Mohammed Aljubori__

# %% [markdown]
# This must be run before anything else

# %%
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly import tools

import numpy as np
import pandas as pd
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# 2a.	Figure 1) A Choropleth map showing the 2016 county by county senate election results in the state of Georgia. The map should show the map of Georgia and only Georgia.
# i.	For each county, compare the columns “demsen16”, “repsen16”, and “othersen16”.
# If “demsen16” has the highest number, color the county blue in the map.
# If “repsen16” has the highest number, color the county red in the map.
# If “othersen16” has the highest number, color the county white in the map.
# ii.	The border of each county should be black.

# %%
df_sample = pd.read_csv(r'election-context-2018.csv')

#Georgia Rows
GA = df_sample.iloc[358:517]

#Checks what color is needed
#1=blue, 2=red, 3=white
def label_race (row):
    if (row['demsen16'] >= row['repsen16']) and (row['demsen16'] >= row['othersen16']) :
        return '1'
    elif  (row['repsen16'] >= row['demsen16']) and (row['repsen16'] >= row['othersen16']) :
        return '2'
    else:
        return '3'
    return 'Other'

#Applies it
GA['Color'] = GA.apply(label_race, axis=1)
#cleaner DataFrame
Votes = GA.groupby(['fips', 'demsen16', 'repsen16', 'othersen16', 'Color'], as_index=False)
nl = Votes.first()

#Figure
fips = nl['fips']
values = nl['Color']

colorscale = ['blue', 'red', 'white']
fig = ff.create_choropleth(
    fips=fips, values=values, scope=['Georgia'], show_state_data=False,
    colorscale=colorscale, round_legend_values=True, showlegend = False,
    county_outline={'color': 'black', 'width': 0.5},
    exponent_format=True,
    title='Georgia Senate Election Results 2016')
sort=True
iplot(fig)
# Out:
# <div>
#
#
#             <div id="3894d0b6-ee60-406c-9ea8-6d912da436d6" class="plotly-graph-div" style="height:450px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3894d0b6-ee60-406c-9ea8-6d912da436d6")) {
#                     Plotly.newPlot(
#                         '3894d0b6-ee60-406c-9ea8-6d912da436d6',
#                         [{"fill": "toself", "fillcolor": "blue", "hoverinfo": "none", "line": {"color": "black", "width": 0.5}, "mode": "lines", "name": "1", "type": "scatter", "uid": "1fafc276-704e-4bea-9faf-a52939568570", "x": [-83.891922, -83.710685, -83.65860099999999, -83.56506999999999, -83.48943, -83.60235999999999, -83.604728, -83.808267, -83.891922, null, -84.827945, -84.656517, -84.64929699999999, -84.45039799999999, -84.454923, -84.412521, -84.490813, -84.78903199999999, -84.827945, null, -81.39169799999999, -81.19535499999999, -81.115195, -81.113334, -81.050234, -81.002297, -80.840378, -80.89768699999999, -80.984336, -80.930145, -80.99269, -81.065255, -81.075812, -81.035913, -81.138448, -81.18122199999999, -81.138324, -81.173396, -81.22234499999999, -81.193817, -81.235596, -81.263549, -81.39169799999999, null, -83.537385, -83.360028, -83.263306, -83.277647, -83.24086, -83.275933, -83.323055, -83.537385, null, -85.1409509602038, -84.95864, -84.942353, -84.817843, -84.80796, -85.02922699999999, -85.057473, -85.12553, -85.1409509602038, null, -84.458927, -84.457728, -84.281273, -84.243858, -84.263702, -84.292112, -84.29468, -84.353584, -84.3544, -84.395073, -84.38163899999999, -84.458927, null, -84.349414, -84.33667799
#6 bins for color
scl = [
    [0.0, 'rgb(242,240,247)'],#1
    [0.2, 'rgb(218,218,235)'],#2
    [0.4, 'rgb(188,189,220)'],#3
    [0.6, 'rgb(158,154,200)'],#4
    [0.8, 'rgb(117,107,177)'],#5
    [1.0, 'rgb(84,39,143)']#6
]




data = [go.Choropleth(
    colorscale = scl,
    autocolorscale = False,
    locations = state_codes1,
    text = 'Winner Percentage: '+ winners_votes.astype('str') + ' / '+ total_votes.astype('str')  
    ,z = final_avg.astype('int'), 
    locationmode = 'USA-states',
)]

layout = go.Layout(
    title = go.layout.Title(
        text = '2018 US senate election'),
    geo = go.layout.Geo(
        scope = 'usa',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = False)
)
fig = go.Figure(data = data, layout = layout)
iplot(fig, filename = 'd3-cloropleth-map')
# Out:
# <div>
#
#
#             <div id="f637d966-215f-4235-84b0-386ddb144a69" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f637d966-215f-4235-84b0-386ddb144a69")) {
#                     Plotly.newPlot(
#                         'f637d966-215f-4235-84b0-386ddb144a69',
#                         [{"autocolorscale": false, "colorscale": [[0.0, "rgb(242,240,247)"], [0.2, "rgb(218,218,235)"], [0.4, "rgb(188,189,220)"], [0.6, "rgb(158,154,200)"], [0.8, "rgb(117,107,177)"], [1.0, "rgb(84,39,143)"]], "locationmode": "USA-states", "locations": ["AZ", "CA", "CT", "DE", "FL", "HI", "IN", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NJ", "NM", "NY", "ND", "OH", "PA", "RI", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"], "text": ["Winner Percentage: 1191100 / 2384308", "Winner Percentage: 6019422 / 11113364", "Winner Percentage: 787685 / 1386840", "Winner Percentage: 217385 / 362592", "Winner Percentage: 4099505 / 8190005", "Winner Percentage: 276316 / 388351", "Winner Percentage: 1158000 / 2282565", "Winner Percentage: 344575 / 634409", "Winner Percentage: 1491614 / 2299889", "Winner Percentage: 1633371 / 2707090", "Winner Percentage: 2214478 / 4237271", "Winner Percentage: 1566174 / 5184235", "Winner Percentage: 547619 / 1843803", "Winner Percentage: 1254927 / 2442289", "Winner Percentage: 253876 / 504384", "Winner Percentage: 403151 / 698883", "Winner Percentage: 490071 / 972132", "Winner Percentage: 1711654 / 3169310", "Winner Percentage: 376998 / 697012", "Winner Percentage: 3755489 / 6055151", "Winner Percentage: 179720 / 326138", "Winner Percentage: 2355923 / 4410898", "Winner Percentage: 2777680 / 4994643", "Winner Percentage: 231477 / 376738", "Winner Percentage: 1227483 / 2243740", "Winner Percentage: 4260553 / 8371655", "Winner Percentage: 665215 / 1062845", "Winner Percentage: 183529 / 272624", "Winner Percentage: 1910370 / 3351373", "Winner Percentage: 1803364 / 3086168", "Winner Percentage: 288808 / 582911", "Winner Percentage: 1472914 / 2657841", "Winner Percentage: 136210 / 203420"], "type": "choropleth", "uid": "5d9a1da6-5ce6-4808-ae52-11c8c769dbdc", "z": [49, 54, 56, 59, 50, 71, 50, 54, 64, 60, 52, 30, 29, 51, 50, 57, 50, 54, 54, 62, 55, 53, 55, 61, 54, 50, 62, 67, 57, 58, 49, 55, 66]}],
#                         {"geo": {"projection": {"type": "albers usa"}, "scope": "usa", "showlakes": false}, "title": {"text": "2018 US senate election"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('f637d966-215f-4235-84b0-386ddb144a69');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# 4.	Load 1962_2006_walmart_store_openings.csv and use Plotly to create the following map. The map must have a title and legend.
# a.	(Figure 4) Create a Scattergeo map that shows the location of every Walmart store opened since 2000 (including 2000) in the United States.
# b.	The map should show the entire United States.
# c.	If it’s a “Supercenter”, use a dark blue color to fill the marker. If it’s a “Wal-Mart”, use a light blue color.

# %%
dz = pd.read_csv(r'1962_2006_walmart_store_openings.csv')
#Takes only years 2000+
wm = dz.iloc[2352:2993]
#checks if supercenter or not
def center_type (row):
    if (row['type_store'] == 'Supercenter'):
        return '1'
    else:
        return '2'
    return 'Other'
#applies it
wm['color'] = wm.apply(center_type, axis=1)

z1 = wm.groupby(['type_store','color','LAT', 'LON'], as_index=False).first()

scl = [ [0,'lightblue'], [1.0,'blue']]

data = [ go.Scattergeo(
        locationmode = 'USA-states',
        lon = z1['LON'],
        lat = z1['LAT'],
        text = z1['type_store'],
        mode = 'markers',
        marker = dict( 
            size = 5, 
            opacity = 0.8,
            reversescale = True,
            autocolorscale = False,
            symbol = 'circle',
            line = dict(
                width=.5,
                color='rgba(102, 102, 102)'
            ),

        ))]

layout = dict(
        title = 'Walmarts Stores<br>(Hover for Store Type)', 
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = "rgb(250, 250, 250)",
            countrywidth = 0.5,
            subunitwidth = 0.5        
        ),
    )

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="dcb08566-999a-48fb-95d2-1456e23b35d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("dcb08566-999a-48fb-95d2-1456e23b35d1")) {
#                     Plotly.newPlot(
#                         'dcb08566-999a-48fb-95d2-1456e23b35d1',
#                         [{"lat": [25.887983, 25.918758, 25.929571, 26.020283, 26.175020999999997, 26.228759999999998, 26.240637, 26.244013, 26.251909, 26.30116, 26.501582, 26.530144, 26.659294, 27.187828999999997, 27.341158, 27.486448, 27.538658, 27.750655, 27.884256, 27.884565000000002, 27.911201000000002, 27.997387, 28.006247, 28.012240999999996, 28.042799, 28.069754999999997, 28.094144, 28.127972999999997, 28.21981, 28.287883, 28.308978999999997, 28.545741999999997, 28.566183000000002, 28.803978999999998, 28.991134999999996, 29.124610999999998, 29.307346999999996, 29.411583, 29.50198, 29.510203999999998, 29.510562, 29.523294, 29.541285, 29.543653999999997, 29.560581, 29.562179999999998, 29.577359, 29.627737, 29.636429999999997, 29.666781, 29.668489, 29.750897, 29.760833, 29.778526, 29.878578000000005, 29.900075, 29.927675, 29.938005, 29.966454, 29.982746000000002, 30.024749, 30.073775, 30.163368, 30.17202, 30.233865, 30.262276, 30.31144, 30.348584999999996, 30.371623, 30.374654, 30.408807, 30.412228999999996, 30.501271999999997, 30.514401, 30.521962, 30.537938, 30.63928, 30.76635, 30.94336, 31.068459000000004, 31.514066999999997, 31.768849, 31.817344, 31.995623, 32.110421, 32.223023, 32.230408000000004, 32.277215999999996, 32.335122, 32.338126, 32.347752, 32.465621, 32.484978999999996, 32.522902, 32.588536, 32.628858, 32.655401, 32.703008000000004, 32.704499, 32.736931, 32.745373, 32.753671999999995, 32.778479, 32.795466
# d.	Place a marker for each country that has produced a champion. Use the latitude and longitude of the capital of the country as the location.
# i.	You may need to find the latitude and longitude for the capitals yourself.
# e.	The size of the marker should be proportional to the number of champions this country has produced.

# %%
do = pd.read_csv(r'wimbledons_champions.csv')
cities = pd.DataFrame()
cities['wins'] = do.pivot_table(index=['Champion Nationality'], aggfunc='size')
#lat of cities
lat = ['-35.2809', '-15.8267', '45.8150', '50.0755', '40.4168',
       '48.8566','51.5074','52.5200','52.3680','-41.2865',
       '55.7558','44.7866','46.204391','59.3293','38.9072'] 
#lon of cities
lon = ['149.1300', '-47.9218', '15.9819', '14.4378', '-3.7038',
       '2.3522','-0.1278','13.4050','4.9036','174.7762',
       '37.6173','20.4489','6.143158','18.0686','-77.0369',
      
      
      ] 
cities['lat'] = lat
cities['lon'] = lon

insert = [
go.Scattergeo(
            lon = cities['lon'],
            lat = cities['lat'],
            text = cities['wins'],
            mode = 'markers',
            showlegend = False,
            marker = go.scattergeo.Marker(
                size = cities['wins'],
                color = 'red',
                sizemode='area',
                sizemin=1,
            )
    )
]
layout = go.Layout(
    title = go.layout.Title(text = 'Winner World Map'),
    geo = go.layout.Geo(
        resolution = 50,
        scope = 'world',
        showframe = False,
        showcoastlines = True,
        showland = True,
        landcolor = "rgb(229, 229, 229)",
        countrycolor = "rgb(255, 255, 255)" ,
        coastlinecolor = "rgb(255, 255, 255)",
        projection = go.layout.geo.Projection(
            type = 'eckert4'
        ),
    )
)

fig = go.Figure(layout=layout, data=insert)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="69bafb01-5f22-4595-a967-9a799597afdf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("69bafb01-5f22-4595-a967-9a799597afdf")) {
#                     Plotly.newPlot(
#                         '69bafb01-5f22-4595-a967-9a799597afdf',
#                         [{"lat": ["-35.2809", "-15.8267", "45.8150", "50.0755", "40.4168", "48.8566", "51.5074", "52.5200", "52.3680", "-41.2865", "55.7558", "44.7866", "46.204391", "59.3293", "38.9072"], "lon": ["149.1300", "-47.9218", "15.9819", "14.4378", "-3.7038", "2.3522", "-0.1278", "13.4050", "4.9036", "174.7762", "37.6173", "20.4489", "6.143158", "18.0686", "-77.0369"], "marker": {"color": "red", "size": [26, 3, 1, 5, 4, 15, 73, 12, 1, 4, 1, 3, 8, 7, 90], "sizemin": 1, "sizemode": "area"}, "mode": "markers", "showlegend": false, "text": [26.0, 3.0, 1.0, 5.0, 4.0, 15.0, 73.0, 12.0, 1.0, 4.0, 1.0, 3.0, 8.0, 7.0, 90.0], "type": "scattergeo", "uid": "6ae199b9-8374-4e35-9437-b97529a9eeaa"}],
#                         {"geo": {"coastlinecolor": "rgb(255, 255, 255)", "countrycolor": "rgb(255, 255, 255)", "landcolor": "rgb(229, 229, 229)", "projection": {"type": "eckert4"}, "resolution": 50, "scope": "world", "showcoastlines": true, "showframe": false, "showland": true}, "title": {"text": "Winner World Map"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('69bafb01-5f22-4595-a967-9a799597afdf');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
